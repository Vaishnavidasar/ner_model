# %% [markdown]
# # Module 3 - NER

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\nirup\\Downloads\\pipeline'

# %%
os.chdir('C:\\Users\\nirup\\Downloads\\pipeline')

# %%
import pandas as pd
import spacy
from tqdm import tqdm
from spacy.tokens import DocBin
import random
import numpy as np
import csv
from pre_processing import func
from model import func2

# %%
df=func2(func('https://www.myrecipes.com/recipe/blueberry-cheesecake'))

# %%
df
# Out:
#                                               Sentence  newline_after  \
# 0                                      skip to content              2
# 9                               holidays and occasions              1
# 10                                      quick and easy              1
# 12                                    bbq and grilling              1
# 22             recipe box this link opens in a new tab              1
# ..                                                 ...            ...
# 462                        subscribe to our newsletter              2
# 465  meredith corporation myrecipes is a registered...              1
# 466  corporation all rights reserved myrecipes may ...              1
# 471                            link opens in a new tab              2
# 476                           close this dialog window              2
#
#      newline_before  nwords  numbers  nnumbers  nnouns  nverbs  nunits   label
# ...

# %%
data = df.loc[df['label'] ==1 ]
data
# Out:
#                                               Sentence  newline_after  \
# 228    cup graham cracker crumbs about 5 cookie sheets              1
# 229  cup reduced fat vanilla wafer crumbs about 20 ...              1
# 230                                3 tablespoons sugar              1
# 231                        3 tablespoons butter melted              1
# 233     2 cups fresh or frozen wild blueberries thawed              1
# 234                            1 tablespoon cornstarch              1
# 237                                        1 cup sugar              1
# 238                           2 tablespoons cornstarch              1
# 242                         1 cups fat free sour cream              1
# 243                                2 tablespoons sugar              1
# 248      1 cup fresh or frozen thawed wild blueberries              2
# 264              remaining 1 cup blueberry puree aside              2
#
# ...

# %%
def ner_label(data):
    lst=[]
    lst2=[]
    data2 = data.loc[data['label'] ==1 ]
    data2 = data2['Sentence']
    df = data2.to_string()
    nlp = spacy.load("output/model-best")
    doc = nlp(df)
    for ent in doc.ents:
        lst.append(ent.text)
        lst2.append(ent.label_)
        final = pd.DataFrame(list(zip(lst, lst2)),columns =['Name', 'val'])
    return final

# %%
ner_label(df)
# Out:
#                      Name         val
# 0           vanilla wafer  INGREDIENT
# 1                   sugar  INGREDIENT
# 2                  butter  INGREDIENT
# 3             blueberries  INGREDIENT
# 4            cornstarch\n  INGREDIENT
# 5                   sugar  INGREDIENT
# 6              cornstarch  INGREDIENT
# 7              sour cream  INGREDIENT
# 8                   sugar  INGREDIENT
# 9             blueberries  INGREDIENT
# 10  blueberry puree aside  INGREDIENT
